# %% [markdown]
# # Игра угадай число

# %%
from game_number2 import average_value, guess_the_number

# %% [markdown]
# ## Угадываем за 20 попыток (или менее)

# %%
average_value (guess_the_number)
# Out:
# Ваш алгоритм угадывает в среднем за: 5 попыток
# 5
