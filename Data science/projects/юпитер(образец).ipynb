# %%
import random_numbers2

# %%
random_numbers2.score_game(random_numbers2.random_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 random_numbers2.score_game(random_numbers2.random_predict)
#
# NameError: name 'random_numbers2' is not defined

# %%
from random_numbers2 import score_game
from random_numbers2 import random_predict
score_game(random_predict)
# Out:
# Количество попыток: 79
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# 101

# %%
from random_numbers2 import score_game, random_predict
